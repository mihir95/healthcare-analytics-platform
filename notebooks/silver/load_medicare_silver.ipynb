# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
# %run "../config/paths"

# %%
from src.transformation.medicare import*

# %%
df = spark.read.table("bronze.medicare")
df = transformation_medicare(df)
df.write.format("delta").mode("overwrite").saveAsTable("silver.medicare")
