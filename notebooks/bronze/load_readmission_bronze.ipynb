# %%
# %run "../config/paths"

# %%
from src.ingestion.bronze_autoloader import load_bronze

# %%
load_bronze(
    spark, 
    input_path = f"{bronze_path}/cms/readmission/", 
    schema_path = f"{bronze_path}/_schemas/readmission/", 
    checkpoint_path = f"{bronze_path}/_chk/readmission/", 
    table_name = "bronze.readmission", 
    source_name = "readmission"
)
