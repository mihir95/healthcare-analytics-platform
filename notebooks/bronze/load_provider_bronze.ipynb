# %%
# %run "../config/paths"

# %%
from src.ingestion.bronze_autoloader import load_bronze

# %%
load_bronze(
    spark, 
    input_path = f"{bronze_path}/cms/provider", 
    schema_path = f"{bronze_path}/_schemas/provider/",
    checkpoint_path = f"{bronze_path}/_chk/provider/", 
    table_name = "bronze.provider", 
    source_name = "provider"
)
