# %%
# %run "../config/paths"

# %%
from src.ingestion.bronze_autoloader import load_bronze

# %%
load_bronze(
    spark, 
    input_path = f"{bronze_path}/cms/medicare", 
    schema_path = f"{bronze_path}/_schemas/medicare/",
    checkpoint_path = f"{bronze_path}/_chk/medicare/", 
    table_name = "bronze.medicare", 
    source_name = "medicare"
)
