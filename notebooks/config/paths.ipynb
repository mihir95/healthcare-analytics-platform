# %%
bronze_path = "abfss://bronze@adlsmddhealthcaredev.dfs.core.windows.net/"
silver_path = "abfss://silver@adlsmddhealthcaredev.dfs.core.windows.net/"
gold_path = "abfss://gold@adlsmddhealthcaredev.dfs.core.windows.net/"
