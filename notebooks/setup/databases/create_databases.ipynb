# %%
# %run "../../config/paths"

# %%
# %sql
CREATE DATABASE IF NOT EXISTS bronze
MANAGED LOCATION "{abfss://bronze@adlsmddhealthcaredev.dfs.core.windows.net/}"

# %%
# %sql
CREATE DATABASE IF NOT EXISTS silver
MANAGED LOCATION "abfss://silver@adlsmddhealthcaredev.dfs.core.windows.net/"

# %%
# %sql
CREATE DATABASE IF NOT EXISTS gold
MANAGED LOCATION "abfss://gold@adlsmddhealthcaredev.dfs.core.windows.net/"
