# %%
# %sql
describe bronze.readmission

# %%
# %sql

CREATE TABLE IF NOT EXISTS silver.readmission (
  readmission_sk BIGINT GENERATED ALWAYS AS IDENTITY NOT NULL,
  readmission_bk_hash STRING NOT NULL,
  facility_id STRING,
  facility_name STRING,
  state_code STRING,
  measure_name STRING,
  start_date DATE,
  end_date DATE,
  condition_name STRING,
  condition_code STRING,
  performance_year INT,
  number_of_discharges INT,
  number_of_readmissions INT,
  excess_readmission_ratio FLOAT, 
  predicted_readmission_rate FLOAT, 
  expected_readmission_rate FLOAT,
  is_excess_readmission BOOLEAN,
  footnote STRING,
  source_code STRING,
  source_data STRING,
  load_timestamp TIMESTAMP
)
USING DELTA

# %%
# %sql
drop table silver.readmission

# %%
# %sql
show catalogs
