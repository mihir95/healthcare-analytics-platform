# %%
# %sql

CREATE TABLE IF NOT EXISTS silver.provider (
  provider_sk	BIGINT GENERATED ALWAYS AS IDENTITY NOT NULL,
  provider_bk_hash STRING NOT NULL,
  provider_number STRING,
  facility_name STRING,
  city_name STRING,
  state_code STRING,
  zip_code STRING,
  fips_state_code STRING,
  fips_county_code STRING,
  cbsa_code STRING,
  cbsa_urban_rural_ind STRING,
  cbsa_urban_rural_ind_std STRING,
  provider_category_code STRING,
  provider_category_subtype_code STRING,
  general_facility_type_code STRING, 
  bed_count INT,
  certified_bed_count INT,
  certification_date DATE,
  original_participation_date DATE,
  program_termination_code STRING,
  source_code STRING,
  source_data	STRING,
  load_timestamp TIMESTAMP
)
USING DELTA
